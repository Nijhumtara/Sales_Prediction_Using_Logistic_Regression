# %% [markdown]
# # Sales Prediction using Logistic Regression
# ### Age & Estimated Salary → Purchase Prediction

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('customer_dataset.csv')
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# ## Basic Inspection

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# ## Check Missing Value

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# ## Duplicacy Check

# %%
df.duplicated().sum()
df[df.duplicated()]
df.drop_duplicates()
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [367 rows x 3 columns]

# %% [markdown]
# ## Segregate Dataset into X(input) and Y(output)

# %%
x = df.iloc[:, : -1]
x.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
y = df.iloc[:, -1]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %% [markdown]
# ## Spliting The Dataset into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state = 0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ## Predict New Customer Buy or Not?

# %%
age = int(input("Enter New Customer Age: "))
salary = int(input("Enter New Customer Salary: "))
newCust = pd.DataFrame([[age, salary]], columns=['Age', 'EstimatedSalary'])
result = model.predict(sc.transform(newCust))

if result == 1:
    print("Customer will buy")
else:
    print("Customer won't buy")
# Out:
# Enter New Customer Age:  30
# Enter New Customer Salary:  400000
# Customer will buy

# %% [markdown]
# ## Evaluation

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the model: {0}%".format(accuracy_score(y_test, y_pred)*100))
print("Precision of the model: {0}%".format(precision_score(y_test, y_pred)*100))
print("Recall of the model: {0}%".format(recall_score(y_test, y_pred)*100))
print("F1 of the model: {0}%".format(f1_score(y_test, y_pred)*100))
# Out:
# Confusion Matrix:
# [[65  3]
#  [ 8 24]]
# Accuracy of the model: 89.0%
# Precision of the model: 88.88888888888889%
# Recall of the model: 75.0%
# F1 of the model: 81.35593220338984%

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 3))
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.title('Age vs Salary (colored by Purchase)')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Won\'t Buy', 'Will Buy'],
            yticklabels=['Won\'t Buy', 'Will Buy'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
